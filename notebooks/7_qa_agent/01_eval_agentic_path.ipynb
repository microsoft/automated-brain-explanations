# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('..')
from neuro import config
from os.path import join
sys.path.append(join(config.REPO_DIR, 'experiments'))

import dvu
import seaborn as sns
import os
import pandas as pd
from copy import deepcopy
from matplotlib import pyplot as plt
import numpy as np
from neuro import config
import imodelsx.process_results
import neuro.features.qa_questions as qa_questions
import joblib
from tqdm import tqdm
from pprint import pprint
import neuro.viz
from neuro import analyze_helper, viz
fit_encoding = __import__('02_fit_encoding')
dvu.set_style()

results_dir = '/home/chansingh/mntv1/deep-fMRI/encoding/aug4_agentic'
rr, cols_varied, mets = analyze_helper.load_clean_results(results_dir)
# joblib.dump({'r': rr, 'cols_varied': cols_varied, 'mets': mets}, 'results_best_ensemble.pkl')
# data = joblib.load(join(config.RESULTS_DIR_LOCAL, 'results_best_ensemble.pkl'))
# rr, cols_varied, mets = data['r'], data['cols_varied'], data['mets']
metric_sort = 'corrs_test_mean'

def rewrite_num_questions_for_agents_row(row):
    if row['feature_space'] == 'qa_agent':
        return len(row['questions_list']) if isinstance(row['questions_list'], list) else 0
    return row['num_questions_restrict']
rr['num_questions_restrict'] = rr.apply(rewrite_num_questions_for_agents_row, axis=1)
rr.loc[rr.feature_space == 'qa_agent', 'qa_questions_version'] = 'agent'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 100%|██████████| 79/79 [00:13<00:00,  5.81it/s]
# /home/chansingh/imodelsX/imodelsx/process_results.py:99: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[k] = df[k].fillna(np.nan)
# experiment varied these params: ['subject', 'feature_space', 'qa_embedding_model', 'qa_questions_version', 'num_questions_restrict', 'agent_checkpoint', 'num_agent_epochs', 'seed']

# %%
rr.loc[rr.feature_space != 'qa_agent', 'agent_checkpoint'] = 'N/A'
rr['agent_seed'] = rr.apply(lambda x: f"{x['agent_checkpoint']}_{x['seed']}", axis=1)

# %%
# for name, group in rr.groupby('save_dir_unique'):
#     group = group.sort_values('epoch', ascending=True)
#     display(group[['seed', 'subject', 'agent_checkpoint', 'epoch', 'num_questions', 'corrs_tune_pc_mean_weighted_by_explained_var', 'corrs_test_mean']])

# %% [markdown]
# ### Evaluate over agent llms

# %%
r = rr
# r = rr[rr.subject == 'S03']
sns.lineplot(
    r[r.feature_space == 'qa_agent'],
    x='num_questions_restrict',
    y='corrs_test_mean',
    hue='agent_seed',
    style='subject',
    style_order=['S03', 'S02', 'S01'],
    # hue='subject',
    # estimator='mean',
    marker='o',
)
plt.show()

# %% [markdown]
# ### Compare agent llms to prompting-based method

# %%
r = rr
hue_levels = sorted(r["agent_seed"].unique())
style_levels = sorted(r["qa_questions_version"].unique())

g = sns.relplot(
    data=r,
    x="num_questions_restrict",
    y="corrs_test_mean",
    hue="agent_seed",
    hue_order=hue_levels,
    style="qa_questions_version",
    style_order=style_levels,
    col="subject",
    kind="line",
    markers=True,
    ms=6,
    legend="full",
    height=6,
    aspect=0.5,
)

sns.move_legend(g, "center right", bbox_to_anchor=(1.02, 0.5), frameon=False)
plt.show()

# %%
# select a row
examples = rr[(rr.feature_space == 'qa_agent') * (rr.subject == 'S03')].sort_values(by='epoch', ascending=False)[['epoch', 'questions_list']]
examples
# Out:
#     epoch                                     questions_list
# 4     4.0  [Does the input involve persuasion or convinci...
# 67    4.0  [Does the input contain logical reasoning or a...
# 66    3.0  [Does the input mention a location?, Does the ...
# 46    3.0  [Does the input use the imperative mood?, Does...
# 3     3.0  [Does the input involve persuasion or convinci...
# 65    2.0  [Does the input describe a conversation or dia...
# 45    2.0  [Does the input use the imperative mood?, Does...
# 2     2.0  [Does the input mention a location?, Does the ...
# 30    2.0  [Does the input mention objects or artifacts?,...
# 64    1.0  [Does the input involve social interaction?, D...
# 44    1.0  [Does the input include a modal verb?, Does th...
# 29    1.0  [Does the input have more than ten words?, Doe...
# 1     1.0  [Does the input involve social interaction?, D...
# 0     0.0  [Does the input describe an action?, Does the ...
# 28    0.0  [Does the input contain sensory details?, Does...
# 43    0.0  [Does the input describe a color?, Does the in...
# 63    0.0  [Does the input describe an action?, Does the ...

# %%
pprint(examples.iloc[0]['questions_list'])
# Out:
# ['Does the input involve persuasion or convincing someone of something?',
#  'Does the input mention a location?',
#  'Does the input describe spatial relationships?',
#  'Does the input refer to an object?',
#  'Does the input involve social interaction?',
#  'Does the input include moral or ethical judgment?',
#  'Does the input depict someone being caught off guard or surprised by '
#  "another's actions?",
#  'Does the input mention a number?',
#  'Does the input describe an action?',
#  'Does the input describe a sequence of events?',
#  'Does the input mention a person?',
#  'Does the input describe an internal thought or reflection?',
#  'Does the input express an emotion?',
#  'Does the input describe a visual scene?',
#  'Does the input describe a personal memory or reminiscence?',
#  'Does the input involve interpersonal trust or betrayal?',
#  'Does the input depict secrecy, concealment, or withholding information from '
#  'others?',
#  'Does the input involve rules being broken or defied intentionally?',
#  'Does the input describe a physical object in detail?',
#  'Does the input mention a sound?',
#  'Does the input depict physical proximity between characters (e.g., standing '
#  'close, touching)?',
#  'Does the input refer to past events?',
#  'Does the input depict misunderstanding or confusion between people?',
#  'Does the input depict urgency, haste, or time pressure in actions taken by '
#  'characters?',
#  'Does the input depict someone giving instructions, warnings, or advice to '
#  'another person?',
#  'Does the input reference cultural traditions, customs, or practices?',
#  'Does the input reference specific named individuals (proper nouns)?',
#  'Does the input contain dialogue or quoted speech?',
#  'Does the input depict cooperation or teamwork toward a goal?',
#  'Does the input describe a physical sensation?',
#  'Does the input convey surprise or unexpected events?',
#  'Does the input involve scientific concepts or research?',
#  'Does the input involve decision making?',
#  'Does the input reference personal goals, ambitions, or aspirations of an '
#  'individual character?',
#  'Does the input include references to historical events or figures?',
#  'Does the input depict anticipation of a future event with emotional weight?',
#  'Does the input involve uncertainty about outcomes of events?',
#  'Does the input involve movement?',
#  'Does the input contain figurative language?',
#  'Does the input depict someone reacting physically to emotions (e.g., crying, '
#  'shaking)?',
#  'Does the input involve metaphors comparing unrelated concepts in an abstract '
#  'way?',
#  'Does the input refer to family relationships?',
#  'Does the input depict someone recalling sensory details from memory (e.g., '
#  'smell, sound, touch)?',
#  'Does the input refer to money, economics, or trade?',
#  'Does the input involve technology or digital media?',
#  'Does the input describe clothing or appearance?',
#  'Does the input involve competition or games?',
#  'Does the input refer to a body part?',
#  'Does the input include sensory details other than sight and sound (e.g., '
#  'smell, taste, touch)?',
#  'Does the input reference art, music, or literature?',
#  'Does the input mention a specific time or date?',
#  'Does the input involve nature or natural environments?',
#  'Does the input refer to travel or transportation?',
#  'Does the input refer to colors?',
#  'Does the input refer to food or drink?',
#  'Does the input refer to future events?',
#  'Does the input involve religion or spirituality?',
#  'Does the input involve conflict or danger?',
#  'Does the input involve health, illness, or medical situations?',
#  'Does the input reference death or mortality?',
#  'Does the input discuss laws, rules, or regulations?',
#  'Does the input describe weather conditions?',
#  'Does the input involve teaching or learning situations?',
#  'Does the input depict physical danger or risk-taking behavior?',
#  'Does the input depict someone experiencing confusion about what is happening '
#  'in their environment?',
#  'Does the input describe environmental sounds such as water movement, traffic '
#  'noise, or machinery?',
#  'Does the input depict tension between tradition and modernity?',
#  'Does the input reference scientific fieldwork, experiments, or data '
#  'collection?',
#  'Does the input depict waiting for an uncertain outcome over an extended '
#  'period?',
#  'Does the input reference specific animals?',
#  'Does the input describe unusual clothing styles or accessories?',
#  'Does the input depict being physically restrained or limited in movement?',
#  'Does the input reference political disagreement within a group?',
#  'Does the input describe sensory experiences related to temperature?',
#  'Does the input depict someone recalling a vivid childhood experience?',
#  'Does the input reference transportation delays or obstacles?',
#  'Does the input depict an internal moral conflict or choice with significant '
#  'consequences?',
#  'Does the input describe physical obstacles or barriers in the environment?',
#  'Does the input refer to specific geographic regions or countries?',
#  'Does the input describe physical contact with objects?',
#  'Does the input describe physical movements within confined spaces?',
#  'Does the input refer to specific proper names of locations?',
#  'Does the input describe unusual or surreal events?',
#  'Does the input describe physical reactions to surprise?',
#  'Does the input describe communication between specific identifiable '
#  'characters?',
#  'Does the input refer to specific materials or substances?',
#  'Does the input describe physical manipulation of objects?',
#  'Does the input describe landscape features?',
#  'Does the input describe physical sensations caused by movement?',
#  'Does the input refer to specific weather phenomena?',
#  'Does the input describe visual perspectives or vantage points?',
#  'Does the input describe unusual behavior from animals?',
#  'Does the input describe multiple sensory modalities simultaneously?']

# %% [markdown]
# # visualize questions list

# %%
g = group
questions_list_list = g['questions_list'].tolist()

# %%
questions_list_list

# %%
[len(x) for x in questions_list_list]

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
import textwrap

def visualize_question_history(history,
                               wrap_width: int = 28,
                               max_questions: int = 100,
                               figsize: tuple = (12, 9),
                               col_labels: list | None = None):
    """
    Draw a static matrix view of how a list of questions evolves over time.
    
    Parameters
    ----------
    history : list[list[str]]
        Sequential snapshots; each inner list is the questions at that time step.
    wrap_width : int, optional
        Number of characters before a sentence is wrapped onto a new line.
    max_questions : int, optional
        Maximum number of unique questions to display (oldest kept first).
    figsize : tuple, optional
        Width, height of the figure in inches.
    col_labels : list[str] | None
        Optional labels for the time steps (default: T0, T1, …).
    """
    if not history:
        raise ValueError("`history` must contain at least one snapshot.")

    # -------- Collect unique questions (oldest first) -----------------------
    seen = {}
    for snap in history:
        for q in snap:
            if q not in seen and len(seen) < max_questions:
                seen[q] = None
    questions = list(seen.keys())
    n_rows, n_cols = len(questions), len(history)

    # -------- Build presence matrix & state map -----------------------------
    present = [[q in snap for snap in history] for q in questions]
    state   = [['absent'] * n_cols for _ in range(n_rows)]

    for r in range(n_rows):
        for c in range(n_cols):
            if present[r][c]:
                if c == 0 or not present[r][c-1]:
                    state[r][c] = 'added'
                else:
                    state[r][c] = 'existing'
            else:
                # mark the previous cell as 'deleted' if it disappears here
                if c > 0 and present[r][c-1]:
                    state[r][c-1] = 'deleted'

    colors = {'absent':  '#FFFFFF',
              'existing':'#E4ECF7',
              'added':   '#B7F5C9',
              'deleted': '#F8C6C4'}

    # -------- Draw ----------------------------------------------------------
    rcParams.update({'font.size': 8})  # small but legible
    fig, ax = plt.subplots(figsize=figsize)
    ax.set_xlim(0, n_cols)
    ax.set_ylim(0, n_rows)
    ax.invert_yaxis()
    ax.axis('off')

    # Grid cells + text
    for r, q in enumerate(questions):
        wrapped_q = textwrap.fill(q, wrap_width)
        for c in range(n_cols):
            rect = plt.Rectangle((c, r), 1, 1,
                                 facecolor=colors[state[r][c]],
                                 edgecolor='grey', linewidth=0.5)
            ax.add_patch(rect)
            if present[r][c]:
                ax.text(c+0.5, r+0.5, wrapped_q,
                        ha='center', va='center')

    # Column (time-step) labels
    if col_labels is None:
        col_labels = [f"T{c}" for c in range(n_cols)]
    for c, lbl in enumerate(col_labels):
        ax.text(c+0.5, -0.35, lbl, ha='center', va='center',
                fontsize=9, weight='bold')

    plt.tight_layout()
    return fig, ax


# ---------------------------------------------------------------------------
# Minimal demo
if __name__ == "__main__":
    history = [
        ["Does the input contain a question mark?",
         "Does the input mention time?"],
        ["Does the input contain a question mark?",  # persists
         "Does the input mention time?",             # persists
         "Does the input mention location?"],        # new
        ["Does the input mention location?",         # persists
         "Does the input describe physical sensations?"]  # new
    ]
    
    plt.show()

# %%
visualize_question_history(questions_list_list, wrap_width=32, figsize=(12, 30))
